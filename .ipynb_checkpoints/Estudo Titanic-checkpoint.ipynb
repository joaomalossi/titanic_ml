# %% [markdown]
# <h1>Como começar com o Aprendizado Supervisionado <i>(Supervised Learning)</i></h1>
# <br><li>Perform an Exploratory Data Analysis (EDA) on your data set;
# <br><li>Build a quick and dirty model, or a baseline model, which can serve as a comparison against later models that you will build;
# <br><li>Iterate this process. You will do more EDA and build another model;
# <br><li>Engineer features: take the features that you already have and combine them or extract more information from them to eventually come to the last point, which is...
# <br><li>Get a model that performs better.

# %%
# Importando os pacotes Pandas, Matplotlib, Seaborn e Sklearn.
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import tree
from sklearn.metrics import accuracy_score

# Comandos para não abrir os gráficos em uma nova janela e setar o estilo de visualização.
# %matplotlib inline
sns.set()

# %%
# Importando os datasets de teste e treino.
df_train = pd.read_csv('datasets/train.csv')
df_test = pd.read_csv('datasets/test.csv')

# %%
# Visualizar as primeiras linhas do arquivo de treino.
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Visualizar as primeiras linhas do arquivo de teste.
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
# Visualizar as informações do dataset de treino
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
# Visualizar as informações do dataset de treino
df_train.describe()
# Out:
# C:\Users\João\Anaconda3\lib\site-packages\numpy\lib\function_base.py:4274: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000         NaN    0.000000
# 50%     446.000000    0.000000    3.000000         NaN    0.000000
# 75%     668.500000    1.000000    3.000000         NaN    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# ...

# %%
# Visualizar graficamente, através do pacote Seaborn, a quantidade de sobreviventes.
sns.countplot(x='Survived', data=df_train);

# %%
# Criação de uma coluna "Sobreviventes" no dataset.
df_test['Survived'] = 0

# %%
# Salvando um arquivo onde a coluna preditória não tem sobreviventes.
df_test[['PassengerId', 'Survived']].to_csv('datasets/predictions/no_survivors.csv', index=False)

# %% [markdown]
# Após a <i>Análise Exploratória dos Dados</i>, foi criado um gráfico mostrando a quantidade de sobreviventes do desastre.
# <br> Criamos um modelo rápido onde o resultado preditório de sobreviventes foi zero. O arquivo foi enviado para o Kaggle e retornou um score de <B>0.62679</b>, o que não é tão ruim mas pode ser melhorado, visto que ainda não foram utilizadas as features do dataset.
# <br> A partir daqui será criado uma nova exploração de dados para a criação de um modelo com maior assertividade.

# %%
# Utilizando Seaborn será plotado um gráfico mostrando a quantidade de passageiros por sexo.
sns.countplot(x='Sex', data=df_train);

# %%
# Aqui é possível visualizar o número de sobreviventes por sexo.
sns.factorplot(x='Survived', col='Sex', kind='count', data=df_train);

# %% [markdown]
# <b>Análise preliminar:</b> Existe uma predisposição de ter mais sobreviventes do sexo feminino.

# %%
# Utilizando o pacote Pandas para conferir os números de sobreviventes por sexo.
df_train.groupby(['Sex']).Survived.sum()
# Out:
# Sex
# female    233
# male      109
# Name: Survived, dtype: int64

# %%
# Utilziação do Pandas para encontrar a porcentagem de sobreviventes por sexo
print(df_train[df_train.Sex == 'female'].Survived.sum()/df_train[df_train.Sex == 'female'].Survived.count())
print(df_train[df_train.Sex == 'male'].Survived.sum()/df_train[df_train.Sex == 'male'].Survived.count())
# Out:
# 0.742038216561
# 0.188908145581

# %% [markdown]
# <b>Mulheres sobreviventes:</b> 74%<br>
# <b>Homens sobreviventes:</b> 19%

# %% [markdown]
# Agora vamos criar um modelo onde todas as mulheres sobrevivem. Obviamente é um modelo que não está correto, mas servirá de base para comparar com os modelos futuros.

# %%
# Criação de uma coluna para colocar o modelo preditório dizendo que apenas as mulheres sobreviveram.
df_test['Survived'] = df_test.Sex == 'female'
df_test['Survived'] = df_test.Survived.apply(lambda x: int(x))
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Survived
# 0  34.5      0      0   330911   7.8292   NaN        Q         0
# 1  47.0      1      0   363272   7.0000   NaN        S         1
# 2  62.0      0      0   240276   9.6875   NaN        Q         0
# 3  27.0      0      0   315154   8.6625   NaN        S         0
# 4  22.0      1      1  3101298  12.2875   NaN        S         1

# %%
# Salvando o dataset em um nov arquivo.
df_test[['PassengerId', 'Survived']].to_csv('datasets/predictions/women_survive.csv', index=False)

# %% [markdown]
# Mais uma vez o arquivo foi enviado para a avaliação do Kaggle que retornou um score de <b>0.76555</b>

# %% [markdown]
# Voltamos para criar mais um ciclo de EDA (Exploratory Data Analysis) e criação de um novo modelo.

# %%
# Criamos um plot para analisar a relação entre sobreviventes e a classe onde eles estavam.
sns.factorplot(x='Survived', col='Pclass', kind='count', data=df_train);

# %% [markdown]
# <b>Análise preliminar:</b> Passageiros que viajaram na primeira classe tiveram uma maior probabilidade de ficarem vivos. Entretanto, viajantes da terceira classe tiveram uma maior chance de não sobreviver.

# %%
# Plotamos um gráfico para analisar a relação entre os sobreviventes e o local de embarque.
sns.factorplot(x='Survived', col='Embarked', kind='count', data=df_train);

# %% [markdown]
# <b>Análise preliminar:</b> Passageiros embarcaram em Southampton tiveram uma maior probabilidade de sobreviver.

# %% [markdown]
# <h1>EDA com valores numéricos</h1>

# %%
# Utilização do seaborn para plotar um gráfico com base na coluna 'Fare'
sns.distplot(df_train.Fare, kde=False);

# %% [markdown]
# <b>Análise preliminar:</b> A maior parte dos passageiros pagou um valor menor que 100 para viajar no navio.

# %%
# Plotagem de sobreviventes em cima do gráfico Fare
df_train.groupby('Survived').Fare.hist(alpha=0.6);

# %% [markdown]
# <b>Análise preliminar:</b> É possível perceber que quem pagou mais teve uma maior chance de sobreviver ao desastre.

# %%
# Retirada dos valores nulos e plotagem de um gráfico com base na coluna de idade. 
df_train_drop = df_train.dropna()
sns.distplot(df_train_drop.Age, kde=False);

# %%
sns.stripplot(x='Survived', y='Fare', data=df_train, alpha=0.3, jitter=True);

# %%
sns.swarmplot(x='Survived', y='Fare', data=df_train);

# %% [markdown]
# Take-away: Fare definitely seems to be correlated with survival aboard the Titanic

# %%
df_train.groupby('Survived').Fare.describe()
# Out:
# Survived
# 0         count    549.000000
#           mean      22.117887
#           std       31.388207
#           min        0.000000
#           25%        7.854200
#           50%       10.500000
#           75%       26.000000
#           max      263.000000
# 1         count    342.000000
#           mean      48.395408
#           std       66.596998
#           min        0.000000
#           25%       12.475000
#           50%       26.000000
#           75%       57.000000
#           max      512.329200
# Name: Fare, dtype: float64

# %%
sns.lmplot(x='Age', y='Fare', hue='Survived', data=df_train, fit_reg=False, scatter_kws={'alpha':0.5});

# %% [markdown]
# Take-away: It looks like those who survived either paid quite a bit for their ticket or they were young

# %%
# Mostrar as descobertas realizadas até agora em um pairplot geral
sns.pairplot(df_train_drop, hue='Survived');

# %%
# Import modules
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import numpy as np
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

# Figures inline and set visualization style
# %matplotlib inline
sns.set()

# Import data
df_train = pd.read_csv('datasets/train.csv')
df_test = pd.read_csv('datasets/test.csv')

# %%
# Store target variable of training data in a safe place
survived_train = df_train.Survived

# Concatenate training and test sets
data = pd.concat([df_train.drop(['Survived'], axis=1), df_test])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    1309 non-null int64
# Pclass         1309 non-null int64
# Name           1309 non-null object
# Sex            1309 non-null object
# Age            1046 non-null float64
# SibSp          1309 non-null int64
# Parch          1309 non-null int64
# Ticket         1309 non-null object
# Fare           1308 non-null float64
# Cabin          295 non-null object
# Embarked       1307 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 122.7+ KB

# %%
# Impute missing numerical variables
data['Age'] = data.Age.fillna(data.Age.median())
data['Fare'] = data.Fare.fillna(data.Fare.median())

# Check out info of data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    1309 non-null int64
# Pclass         1309 non-null int64
# Name           1309 non-null object
# Sex            1309 non-null object
# Age            1309 non-null float64
# SibSp          1309 non-null int64
# Parch          1309 non-null int64
# Ticket         1309 non-null object
# Fare           1309 non-null float64
# Cabin          295 non-null object
# Embarked       1307 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 122.7+ KB

# %%
data = pd.get_dummies(data, columns=['Sex'], drop_first=True)
data.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked  Sex_male
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S       1.0
# 1  38.0      1      0          PC 17599  71.2833   C85        C       0.0
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S       0.0
# 3  35.0      1      0            113803  53.1000  C123        S       0.0
# 4  35.0      0      0            373450   8.0500   NaN        S       1.0

# %%
# Select columns and view head
data = data[['Sex_male', 'Fare', 'Age','Pclass', 'SibSp']]
data.head()
# Out:
#    Sex_male     Fare   Age  Pclass  SibSp
# 0       1.0   7.2500  22.0       3      1
# 1       0.0  71.2833  38.0       1      1
# 2       0.0   7.9250  26.0       3      0
# 3       0.0  53.1000  35.0       1      1
# 4       1.0   8.0500  35.0       3      0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 417
# Data columns (total 5 columns):
# Sex_male    1309 non-null float64
# Fare        1309 non-null float64
# Age         1309 non-null float64
# Pclass      1309 non-null int64
# SibSp       1309 non-null int64
# dtypes: float64(3), int64(2)
# memory usage: 61.4 KB

# %%
data_train = data.iloc[:891]
data_test = data.iloc[891:]

# %%
X = data_train.values
test = data_test.values
y = survived_train.values

# %%
# Instantiate model and fit to data
clf = tree.DecisionTreeClassifier(max_depth=3)
clf.fit(X, y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
# Make predictions and store in 'Survived' column of df_test
Y_pred = clf.predict(test)
df_test['Survived'] = Y_pred

# %%
df_test[['PassengerId', 'Survived']].to_csv('datasets/predictions/1st_dec_tree.csv', index=False)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42, stratify=y)

# %%
# Setup arrays to store train and test accuracies
dep = np.arange(1, 9)
train_accuracy = np.empty(len(dep))
test_accuracy = np.empty(len(dep))

# Loop over different values of k
for i, k in enumerate(dep):
    # Setup a k-NN Classifier with k neighbors: knn
    clf = tree.DecisionTreeClassifier(max_depth=k)

    # Fit the classifier to the training data
    clf.fit(X_train, y_train)

    #Compute accuracy on the training set
    train_accuracy[i] = clf.score(X_train, y_train)

    #Compute accuracy on the testing set
    test_accuracy[i] = clf.score(X_test, y_test)

# Generate plot
plt.title('clf: Varying depth of tree')
plt.plot(dep, test_accuracy, label = 'Testing Accuracy')
plt.plot(dep, train_accuracy, label = 'Training Accuracy')
plt.legend()
plt.xlabel('Depth of tree')
plt.ylabel('Accuracy')
plt.show()
